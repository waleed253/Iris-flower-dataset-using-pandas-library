# %%
import pandas as pd

# %%
df=pd.read_csv("IRIS.csv")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.species.describe()
# Out:
# count             150
# unique              3
# top       Iris-setosa
# freq               50
# Name: species, dtype: object

# %%
df.insert(4,"mean features",'')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width mean features  \
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...           ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
#             species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# ...

# %%
col=df.loc[:,sepal_length:petal_widht]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-30c4dd803677> in <module>
# ----> 1 col=df.loc[:,sepal_length:petal_widht]
#
# NameError: name 'sepal_length' is not defined

# %%
df["mean features"]=col.mean(axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-378e79e939c9> in <module>
# ----> 1 df["mean features"]=col.mean(axis=1)
#
# NameError: name 'col' is not defined

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width mean features  \
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...           ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
#             species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# ...

# %%
df.describe(include ='all')
# Out:
#         sepal_length  sepal_width  petal_length  petal_width mean features  \
# count     150.000000   150.000000    150.000000   150.000000           150
# unique           NaN          NaN           NaN          NaN             1
# top              NaN          NaN           NaN          NaN
# freq             NaN          NaN           NaN          NaN           150
# mean        5.843333     3.054000      3.758667     1.198667           NaN
# std         0.828066     0.433594      1.764420     0.763161           NaN
# min         4.300000     2.000000      1.000000     0.100000           NaN
# 25%         5.100000     2.800000      1.600000     0.300000           NaN
# 50%         5.800000     3.000000      4.350000     1.300000           NaN
# 75%         6.400000     3.300000      5.100000     1.800000           NaN
# max         7.900000     4.400000      6.900000     2.500000           NaN
#
#             species
# count           150
# unique            3
# ...

# %%
df["species"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df["species"].replace({'Iris-setosa':'setosa','Iris-versicolor':'versi','Iris-virginica':virgin},inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-ea36c2a7c7b3> in <module>
# ----> 1 df["species"].replace({'Iris-setosa':'setosa','Iris-versicolor':'versi','Iris-virginica':virgin},inplace=True)
#
# NameError: name 'virgin' is not defined

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width mean features  \
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...           ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
#             species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# ...

# %%
df.to_csv('Newcsv.csv')
